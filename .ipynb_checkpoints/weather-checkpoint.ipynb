# %%
#import neccessary modules
from citipy import citipy
import pandas as pd
import random
import numpy as np
from config import gkey
from config import wkey


#get a city at the center of the equator and seed a new dataframe
cities = []
equator_city = citipy.nearest_city(0,0)
equator_city_name = equator_city.city_name.capitalize()
equator_country_code = equator_city.country_code.upper()
cities.append(equator_city_name + ',' + equator_country_code)

#generate 500 unique cities 
# show relationship between distance and temp
while len(np.unique(cities)) < 500:
    city = citipy.nearest_city(random.randint(-90,90), random.randint(-180,180))
    cities.append(('{},{}'.format(city.city_name.capitalize(),city.country_code.upper())))
cities
# Out:
# ['Takoradi,GH',
#  'Punta arenas,CL',
#  'Komsomolskiy,RU',
#  'Vaini,TO',
#  'Rikitea,PF',
#  'Srednekolymsk,RU',
#  'Hilo,US',
#  'Kapaa,US',
#  'Dikson,RU',
#  'Hervey bay,AU',
#  'Malkapur,IN',
#  'Jamestown,SH',
#  'Isla mujeres,MX',
#  'Bredasdorp,ZA',
#  'Khatanga,RU',
#  'Riyadh,SA',
#  'Wellington,NZ',
#  'Butaritari,KI',
#  'Margate,ZA',
#  'Ponta do sol,CV',
#  'Mount gambier,AU',
#  'Hongjiang,CN',
#  'Cherskiy,RU',
#  'Thompson,CA',
#  'Arraial do cabo,BR',
#  'Victoria,SC',
#  'Mumford,GH',
#  'Nikolskoye,RU',
#  'Ormara,PK',
#  'Iqaluit,CA',
#  'Rikitea,PF',
#  'Puerto ayora,EC',
#  'Chuy,UY',
#  'Lebu,CL',
#  'Roald,NO',
#  'Avarua,CK',
#  'Haines junction,CA',
#  'Hofn,IS',
#  'Bambous virieux,MU',
#  'Vila franca do campo,PT',
#  'Hermanus,ZA',
#  'Taolanaro,MG',
#  'East london,ZA',
#  'Punta arenas,CL',
#  'Tuktoyaktuk,CA',
#  'Hermanus,ZA',
#  'Amahai,ID',
#  'Kangaatsiaq,GL',
#  'Savalou,BJ',
#  'Pasighat,IN',
#  'Tiksi,RU',
#  'Rikitea,PF',
#  'Castro,CL',
# ...

# %%
#generate 500 unique cities 
# show relationship between distance and temp
while len(np.unique(cities)) < 500:
    city = citipy.nearest_city(random.randint(-120.9762,41.25), random.randint(-180,180))
    cities.append(('{},{}'.format(city.city_name.capitalize(),city.country_code.upper())))

# %%
import requests
#get exact latitude and longitude using google geocode
latitude = []
longitude = []

for city in cities:
    geo_data = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(city, gkey)).json()
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]
    latitude.append(lat)
    longitude.append(lng)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-972ead66247e> in <module>()
#       6 for city in cities:
#       7     geo_data = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(city, gkey)).json()
# ----> 8     lat = geo_data["results"][0]["geometry"]["location"]["lat"]
#       9     lng = geo_data["results"][0]["geometry"]["location"]["lng"]
#      10     latitude.append(lat)
#
# IndexError: list index out of range

# %%
test_country = cities[20]
geo_data = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(test_country, gkey)).json()
geo_data["results"][0]["geometry"]["location"]["lat"]

cities[111]
# Out:
# 'Buala,SB'
